# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("diabetes.csv")
df2 = pd.read_csv("HR-Employee-Attrition.csv")
df3 = pd.read_csv("Sales Data.csv")

# %%
df1.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
# df2.head(2)

# %%
# df3.head()

# %% [markdown]
# ### We will go with the diabetes dataset.

# %% [markdown]
# ### Basic statistics:
# - shape
# - info()
# - describe()
# - null_values()
# - duplicate values()
# - correlation()

# %%
# importing diabetes dataset.

df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape # 768 rows and 9 columns/attributes
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe() # WITH THIS TBALE WE CAN UNDERSTAND THE STATISTICAL MEASURES. TO BETTER UNDERSTAND WE WILL PLOT GRAPHS.
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum() # NO NULL VALUES.
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df[df.duplicated()] # NO DUPLICATE VALUES.
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True, linewidths = 0.1 )
# Out:
# <Axes: >

# %% [markdown]
# #### From above correlation graph we can undestand the following:
#
# - **Pregnancies, glucose, insuline, BMI, age** are highly to moderately correlated with diabetes outcome. These will be helpful in predicting diabetes.
#
# - while other attributes such as **bloodpresure, skintheickness, diabetes pedigree function** are least correlated with outcome attribute.
#
# **NOTE**: Almost all these factors contribute to the recognition of diabetes, but somehow some attributes of this dataset dosen't correlates with outcome, this dosen't mean they don't contribute to diabetes. We will study these attributes further.

# %% [markdown]
# ### **Note** - General information about these columns :
#
# - **Pregnancies**: Represents the number of pregnancies, providing insight into potential gestational diabetes risk.
#
# - **Glucose**: Indicates blood sugar levels, a crucial diagnostic factor for diabetes.
#
# - **BloodPressure**: Measures blood pressure, which is a risk factor for diabetes.
#
# - **SkinThickness**: Represents skinfold thickness, used to estimate body fat percentage.
#
# - **Insulin**: Indicates insulin levels, a hormone critical for regulating blood sugar.
#
# - **BMI** (Body Mass Index): It is a measure of weight relative to height, highlighting obesity risk.
#
# - **DiabetesPedigreeFunction**: Quantifies genetic risk to diabetes based on family history.
#
# - **Age**: Represents the individual's age, a key factor in diabetes risk, particularly for type 2 diabetes.
#
# - **Outcome**: The target variable, typically binary (1 for diabetes, 0 for no diabetes), used for predictions and analysis.

# %%
df.columns = df.columns.str.lower() # renaming columns

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6      148             72             35        0  33.6
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1

# %%
sns.pairplot(df)

# %% [markdown]
# #### By the first look of dataset, there seems to be missing values or error in obervations.These are represented as 0's in the dataset. So lets try to TRUNCATE or CAP them.

# %% [markdown]
# ### Univariate analysis.

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ### Pregnancies column

# %%
plt.figure()

plt.subplot(1,2,1)
sns.histplot(df.pregnancies, bins = 40) # this is right skewed data.

plt.subplot(1,2,2)
sns.boxplot(df.pregnancies)# there are outliers, these are possible in medical terms.
# Out:
# <Axes: >

# %% [markdown]
# ### Glucose column

# %%
plt.figure()

plt.subplot(1,2,1)
sns.histplot(df.glucose, bins = 40) 

plt.subplot(1,2,2)
sns.boxplot(df.glucose)
# Out:
# <Axes: >

# %% [markdown]
# #### GLucose value cannot be 0, also from the graph we can see that something is unusual. There might data entry error, observation error in case of 0 values. So we will cap them to lower bound.
#
# #### We will go with z-score as the data is close to normal distribution.

# %%
df[df.glucose==0]
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      diabetespedigreefunction  age  outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
df.glucose.describe()
# Out:
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: glucose, dtype: float64

# %%
lower_bound = df.glucose.mean() - 2.5 * df.glucose.std()

# %%
lower_bound
# Out:
# 40.96298576215945

# %%
df[df.glucose < lower_bound] # perfect, now we will replace these values with lower bound.
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      diabetespedigreefunction  age  outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
df.glucose[df.glucose < lower_bound] = lower_bound

# %%
sns.histplot(df.glucose, bins = 50)
# Out:
# <Axes: xlabel='glucose', ylabel='Count'>

# %% [markdown]
# ### BloodPressure column

# %%
df[df.bloodpressure == 0]
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 7             10    115.0              0              0        0  35.3
# 15             7    100.0              0              0        0  30.0
# 49             7    105.0              0              0        0   0.0
# 60             2     84.0              0              0        0   0.0
# 78             0    131.0              0              0        0  43.2
# 81             2     74.0              0              0        0   0.0
# 172            2     87.0              0             23        0  28.9
# 193           11    135.0              0              0        0  52.3
# 222            7    119.0              0              0        0  25.2
# 261            3    141.0              0              0        0  30.0
# 266            0    138.0              0              0        0  36.3
# 269            2    146.0              0              0        0  27.5
# ...

# %%
len(df[df.bloodpressure == 0])
# Out:
# 35

# %%
sns.histplot(df.bloodpressure, bins = 40)
# Out:
# <Axes: xlabel='bloodpressure', ylabel='Count'>

# %%
lower_bound_preg = df.bloodpressure.mean() - 2 * df.bloodpressure.std()

# %%
lower_bound
# Out:
# 40.96298576215945

# %%
df.bloodpressure[df.bloodpressure == 0] = lower_bound_preg

# %%
print(df.bloodpressure.mean())
print(df.bloodpressure.mode())
print(df.bloodpressure.std())
# Out:
# 70.49060534414696
# 0    70.0
# Name: bloodpressure, dtype: float64
# 14.939547204727033

# %%
sns.histplot(df.bloodpressure)
# Out:
# <Axes: xlabel='bloodpressure', ylabel='Count'>

# %% [markdown]
# #### Note: The dataset size is small. So removing these values is not feasible, so we did capping instead of removing them.

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ### Skinthickness column

# %%
df[df.skinthickness == 0]
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 2              8    183.0      64.000000              0        0  23.3
# 5              5    116.0      74.000000              0        0  25.6
# 7             10    115.0      30.393854              0        0  35.3
# 9              8    125.0      96.000000              0        0   0.0
# 10             4    110.0      92.000000              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 757            0    123.0      72.000000              0        0  36.3
# 758            1    106.0      76.000000              0        0  37.5
# 759            6    190.0      92.000000              0        0  35.5
# 762            9     89.0      62.000000              0        0  22.5
# 766            1    126.0      60.000000              0        0  30.1
#
#      diabetespedigreefunction  age  outcome
# 2                       0.672   32        1
# ...

# %%
plt.subplot(1,2,1)
sns.boxplot(df.skinthickness)

plt.subplot(1,2,2)
sns.histplot(df.skinthickness, bins = 50) # again, we cannot remove such large values.
# Out:
# <Axes: xlabel='skinthickness', ylabel='Count'>

# %%
skin_median = df.skinthickness.median()

# %%
df.skinthickness[df.skinthickness == 0] = skin_median

# %%
sns.histplot(df.skinthickness, bins = 40)
# Out:
# <Axes: xlabel='skinthickness', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ### Insulin column

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.boxplot(df.insulin)

plt.subplot(1,2,2)
sns.histplot(df.insulin, bins = 50)
# Out:
# <Axes: xlabel='insulin', ylabel='Count'>

# %% [markdown]
# #### These outliers are missing values or error values

# %%
df[df.insulin==0] # such large values. Not possible to remove them.
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6    148.0      72.000000             35        0  33.6
# 1              1     85.0      66.000000             29        0  26.6
# 2              8    183.0      64.000000             23        0  23.3
# 5              5    116.0      74.000000             23        0  25.6
# 7             10    115.0      30.393854             23        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9    170.0      74.000000             31        0  44.0
# 762            9     89.0      62.000000             23        0  22.5
# 764            2    122.0      70.000000             27        0  36.8
# 766            1    126.0      60.000000             23        0  30.1
# 767            1     93.0      70.000000             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
df.insulin.mean()
# Out:
# 79.79947916666667

# %%
df.insulin.median()
# Out:
# 30.5

# %% [markdown]
# #### From above two stats values, we can see the effect of outliers. When our dataset has outliers our mean is not the actual representation of average value. In this case we use median which is robust to outliers and thus becomes the true average value.

# %%
df[df.insulin == 0]
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6    148.0      72.000000             35        0  33.6
# 1              1     85.0      66.000000             29        0  26.6
# 2              8    183.0      64.000000             23        0  23.3
# 5              5    116.0      74.000000             23        0  25.6
# 7             10    115.0      30.393854             23        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9    170.0      74.000000             31        0  44.0
# 762            9     89.0      62.000000             23        0  22.5
# 764            2    122.0      70.000000             27        0  36.8
# 766            1    126.0      60.000000             23        0  30.1
# 767            1     93.0      70.000000             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
insulin_median = df.insulin.mean() - df.insulin.std()

# %%
insulin_median

# %%
df.insulin[df.insulin == 0] = insulin_median

# %%
sns.histplot(df.insulin)
# Out:
# <Axes: xlabel='insulin', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ### BMI column

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.boxplot(df.bmi)

plt.subplot(1,2,2)
sns.histplot(df.bmi, bins = 50)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %% [markdown]
# #### In above case we can definately use z-score method because our data follows normal distribution

# %%
lower_bound_bmi = df.bmi.mean() - 1.5 * df.bmi.std()

# %%
lower_bound_bmi
# Out:
# 20.166337644436837

# %%
df.bmi[df.bmi == 0] = lower_bound_bmi

# %%
sns.histplot(df.bmi)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ### Diabetes pedigree function (heredity information)

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.boxplot(df.diabetespedigreefunction)

plt.subplot(1,2,2)
sns.histplot(df.diabetespedigreefunction, bins = 50)
# Out:
# <Axes: xlabel='diabetespedigreefunction', ylabel='Count'>

# %% [markdown]
# #### Extreme greater outlier values are special medical cases. For these values, we requires specialist.

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %% [markdown]
# ### Age column

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.boxplot(df.age)

plt.subplot(1,2,2)
sns.histplot(df.age, bins = 50)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df[df.age == 0]
# Out:
# Empty DataFrame
# Columns: [pregnancies, glucose, bloodpressure, skinthickness, insulin, bmi, diabetespedigreefunction, age, outcome]
# Index: []

# %%
df.head(5)
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6    148.0           72.0             35        0  33.6
# 1            1     85.0           66.0             29        0  26.6
# 2            8    183.0           64.0             23        0  23.3
# 3            1     89.0           66.0             23       94  28.1
# 4            0    137.0           40.0             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### outcome column

# %%
sns.histplot(df.outcome)
# Out:
# <Axes: xlabel='outcome', ylabel='Count'>

# %% [markdown]
# #### outcome column is clearly imbalanced data column, but this might be indication of something. It might indicate that 0 value represent non-diabetic person where as 1 represent diabetic person. So we won't change anything in outcome column.

# %% [markdown]
# ### Data handling and transformation is complete.

# %%
df.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6    148.0           72.0             35        0  33.6
# 1            1     85.0           66.0             29        0  26.6
# 2            8    183.0           64.0             23        0  23.3
# 3            1     89.0           66.0             23       94  28.1
# 4            0    137.0           40.0             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Feature importance analysis

# %%
# Splitting

X = df.drop(['outcome', 'skinthickness'], axis = 1)
y = df['outcome']

# %%
from sklearn.ensemble import ExtraTreesRegressor
select = ExtraTreesRegressor()
select.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(select.feature_importances_)
# Out:
# [0.10728984 0.30349757 0.1010601  0.07673481 0.15476673 0.11220424
#  0.14444672]

# %%
plt.figure(figsize = (8,4))
fig_importances = pd.Series(select.feature_importances_, index=X.columns)
fig_importances.nlargest(20).plot(kind='barh')
plt.savefig('fig_importance_plot.png')  # Save the plot as an image
plt.show()

# %% [markdown]
# #### from the above graph we can understand the importance of each feature. Here glucose and bmi level appears to be a contributing factor in diabetes and this is actually true in real sense.

# %%
df.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6    148.0           72.0             35        0  33.6
# 1            1     85.0           66.0             29        0  26.6
# 2            8    183.0           64.0             23        0  23.3
# 3            1     89.0           66.0             23       94  28.1
# 4            0    137.0           40.0             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Modeling

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 32, test_size=0.21, shuffle= True)

# %% [markdown]
# #### This is a classification problem. Thus we will use classification algorithms.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# stand_scaler = StandardScaler()
minmax = MinMaxScaler()

# %%
X_train = pd.DataFrame(minmax.fit_transform(X_train), columns=minmax.get_feature_names_out())
X_test = pd.DataFrame(minmax.transform(X_test), columns = minmax.get_feature_names_out())

# %%
X_train.shape
# Out:
# (606, 7)

# %%
X_test.shape
# Out:
# (162, 7)

# %%
# !pip install xgboost

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB

from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.svm import SVC

from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier

from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, precision_recall_curve, recall_score, f1_score, confusion_matrix

# %%
models_list = {
    'lr': LogisticRegression(),
    'bnb' : BernoulliNB(),
    'Gnb': GaussianNB(),
    'mnb': MultinomialNB(),
    'knc': KNeighborsClassifier(),
    'dtc': DecisionTreeClassifier(),
    'rfc': RandomForestClassifier(),
    'svc': SVC(),
    'adaboost': AdaBoostClassifier(),
    'gboost': GradientBoostingClassifier(),
    'bagging' : BaggingClassifier(),
    'extratrees': ExtraTreesClassifier(),
    'xgb': XGBClassifier()
}
models_prediction = {}

# %%
for model_name, models in models_list.items():
    
    model = models.fit(X_train,y_train)
    
    y_pred = model.predict(X_test)

    print(model_name)
    print('accuracy_score:', accuracy_score(y_test, y_pred))
#     print('precision_score:', precision_score(y_test, y_pred))
    print('recall_score:', recall_score(y_test, y_pred))
#     print('f1_score:', f1_score(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred), '\n')
    
    models_prediction[model_name  + 'recall_score'] = recall_score(y_test, y_pred)
# Out:
# lr
# accuracy_score: 0.8024691358024691
# recall_score: 0.6607142857142857
# [[93 13]
#  [19 37]]
#
# bnb
# accuracy_score: 0.654320987654321
# recall_score: 0.0
# [[106   0]
#  [ 56   0]]
#
# Gnb
# accuracy_score: 0.808641975308642
# recall_score: 0.7321428571428571
# [[90 16]
#  [15 41]]
#
# mnb
# accuracy_score: 0.654320987654321
# recall_score: 0.0
# [[106   0]
#  [ 56   0]]
#
# knc
# accuracy_score: 0.7654320987654321
# recall_score: 0.6785714285714286
# [[86 20]
#  [18 38]]
#
# dtc
# accuracy_score: 0.7407407407407407
# recall_score: 0.625
# [[85 21]
#  [21 35]]
#
# rfc
# accuracy_score: 0.7962962962962963
# recall_score: 0.6785714285714286
# [[91 15]
#  [18 38]]
#
# svc
# accuracy_score: 0.7777777777777778
# recall_score: 0.625
# [[91 15]
#  [21 35]]
#
# adaboost
# accuracy_score: 0.7901234567901234
# recall_score: 0.6428571428571429
# [[92 14]
#  [20 36]]
#
# gboost
# accuracy_score: 0.8271604938271605
# recall_score: 0.75
# [[92 14]
#  [14 42]]
#
# bagging
# ...

# %%
best_model = max(models_prediction, key = models_prediction.get)
best_score = models_prediction[best_model]
print(f"{best_model} --> {best_score}")
# Out:
# gboost_precision_score --> 0.75

# %% [markdown]
# #### In medical field, its very important to achieve a balance in recall and precision to reduce cases of false positive and false negative. In our case we achieve this using Gradient boost algorithm. Therefore we will use it as our final model for prediction.

# %% [markdown]
# ### Final model --> Gradient boost
